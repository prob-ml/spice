# %%
import os
import torch

os.environ["MKL_NUM_THREADS"]="1"
os.environ["NUMEXPR_NUM_THREADS"]="1"
os.environ["OMP_NUM_THREADS"]="1"

import sys

import pytorch_lightning as pl
from omegaconf import DictConfig, OmegaConf
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.loggers import TensorBoardLogger
from torch.utils.data import random_split
from torch_geometric.data import DataLoader

from spatial.merfish_dataset import FilteredMerfishDataset, MerfishDataset, SyntheticDataset0, SyntheticDataset1, SyntheticDataset2, SyntheticDataset3
from spatial.models.monet_ae import MonetAutoencoder2D, TrivialAutoencoder, MonetDense
from spatial.train import train
from spatial.predict import test

# makes the notebook loadable
import warnings
warnings.filterwarnings('ignore')

# %%
import hydra
from hydra.experimental import compose, initialize

test_loss_rad_dict = {}
zero_separated_loss_dict = {}


for tol in [0, 0.25, 0.5, 0.75, 1, 1.5, 2]:
    with initialize(config_path="../config"):
        cfg_from_terminal = compose(config_name="config0")
        OmegaConf.update(cfg_from_terminal, "model.kwargs.hidden_dimensions", [128, 128])
        OmegaConf.update(cfg_from_terminal, "training.logger_name", f"synthetic0_zeroinf")
        OmegaConf.update(cfg_from_terminal, "radius", 30)
        OmegaConf.update(cfg_from_terminal, "datasets.dataset.splits", 2)
        OmegaConf.update(cfg_from_terminal, "datasets.dataset.tol", tol)
        OmegaConf.update(cfg_from_terminal, "training.filepath", f"MonetDense__[128, 128]__[0]__30__synthetic0_zeroinf__{tol}")
        output = test(cfg_from_terminal)
        trainer, l1_losses, inputs, gene_expressions, celltypes, test_results = output
        print(inputs)
        break
        test_loss_rad_dict[tol] = test_results[0]['test_loss']
        num_zeros = torch.sum(inputs[:, 0] == 0)
        n = len(inputs[:, 0])
        loss_for_non_zeros = (n / (n - num_zeros)) * torch.mean(((inputs[:, 0] - gene_expressions[:, 0]) ** 2) * (inputs[:, 0] != 0).reshape(1, -1))
        loss_for_zeros = (n / num_zeros) * torch.mean(((inputs[:, 0] - gene_expressions[:, 0]) ** 2) * (inputs[:, 0] == 0).reshape(1, -1))
        loss = torch.mean((inputs[:, 0] - gene_expressions[:, 0]) ** 2)
        zero_separated_loss_dict[tol] = {
            "Loss (MSE)": loss.item(),
            "Loss for non-0s": loss_for_non_zeros.item(),
            "Loss for 0s": loss_for_zeros.item()
        }
# Out:
#   0%|                                                                                   | 0/24 [00:00<?, ?it/s]
# tensor([0.8755, 0.3365, 0.3365, 0.7885, 0.7885, 0.1823, 0.4700, 0.8755, 0.8755,
#         1.0296, 1.0296, 0.4700, 0.7885, 0.5878, 0.4700, 0.3365, 0.4700, 1.0986,
#         0.6931, 1.0296, 0.6931, 1.2238, 0.5878, 1.0296, 0.7885, 1.0986, 0.6931,
#         1.1632, 0.0000, 1.0986, 0.0000, 1.1632, 1.1632, 1.0986, 0.9555, 0.3365,
#         0.4700, 0.0000, 0.6931, 0.6931, 0.8755, 0.7885, 0.9555, 0.7885, 0.4700,
#         0.7885, 0.7885, 1.2809, 0.7885, 0.6931, 0.6931, 1.0296, 1.4816, 0.4700,
#         0.8755, 0.8755, 0.7885, 1.1632, 0.4700, 0.4700, 0.4700, 0.4700, 0.8755,
#         1.0296, 0.4700, 0.7885, 0.7885, 0.8755, 0.7885, 0.9555, 1.0296, 0.4700,
#         0.6931, 1.1632, 0.3365, 0.5878, 0.6931, 0.3365, 0.7885, 0.1823, 0.5878,
#         0.9555, 0.9555, 0.6931, 1.0296, 0.9555, 0.6931, 1.0986, 1.0296, 0.4700,
#         0.3365, 1.0296, 0.5878, 0.5878, 0.9555, 0.5878, 0.3365, 0.3365, 0.8755,
#         0.5878, 0.4700, 0.9555, 0.5878, 0.3365, 0.8755, 0.8755, 0.7885, 0.3365,
#         0.3365, 0.3365, 0.5878, 0.7885, 0.7885, 0.1823, 0.3365, 0.9555, 0.3365,
#         0.3365, 0.5878, 0.5878, 0.4700, 0.3365, 0.3365, 0.3365, 0.0000, 0.5878,
#         0.4700, 0.3365, 0.5878, 0.6931, 1.0296, 1.2809, 0.8755, 1.2238, 0.0000,
#         0.0000, 0.9555, 0.3365, 0.7885, 1.1632, 0.7885, 0.7885, 0.6931, 0.1823,
#         1.1632, 0.9555, 0.6931, 0.9555, 0.5878])
#  25%|██████████████████▊                                                        | 6/24 [00:08<00:26,  1.50s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 17
#      15 OmegaConf.update(cfg_from_terminal, "datasets.dataset.tol", tol)
#      16 OmegaConf.update(cfg_from_terminal, "training.filepath", f"MonetDense__[128, 128]__[0]__30__synthetic0_zeroinf__{tol}")
# ---> 17 output = test(cfg_from_terminal)
#      18 trainer, l1_losses, inputs, gene_expressions, celltypes, test_results = output
#      19 print(inputs)
#
# File ~/spatial/spatial/predict.py:27, in test(cfg, data)
#      25         data = instantiate(cfg.datasets.dataset[0], train=False)
#      26     else:
# ---> 27         data = instantiate(cfg.datasets.dataset, train=False)
#      29 # ensuring data dimension is correct
#      30 if cfg.model.kwargs.observables_dimension != data[0].x.shape[1]:
#
# File ~/.cache/pypoetry/virtualenvs/spatial-G_n0JvVf-py3.10/lib/python3.10/site-packages/hydra/_internal/instantiate/_instantiate2.py:226, in instantiate(config, *args, **kwargs)
#     223     _convert_ = config.pop(_Keys.CONVERT, ConvertMode.NONE)
#     224     _partial_ = config.pop(_Keys.PARTIAL, False)
# --> 226     return instantiate_node(
#     227         config, *args, recursive=_recursive_, convert=_convert_, partial=_partial_
#     228     )
#     229 elif OmegaConf.is_list(config):
#     230     # Finalize config (convert targets to strings, merge with kwargs)
#     231     config_copy = copy.deepcopy(config)
#
# File ~/.cache/pypoetry/virtualenvs/spatial-G_n0JvVf-py3.10/lib/python3.10/site-packages/hydra/_internal/instantiate/_instantiate2.py:347, in instantiate_node(node, convert, recursive, partial, *args)
#     342                 value = instantiate_node(
#     343                     value, convert=convert, recursive=recursive
#     344                 )
#     345             kwargs[key] = _convert_node(value, convert)
# --> 347     return _call_target(_target_, partial, args, kwargs, full_key)
#     348 else:
#     349     # If ALL or PARTIAL non structured or OBJECT non structured,
#     350     # instantiate in dict and resolve interpolations eagerly.
#     351     if convert == ConvertMode.ALL or (
#     352         convert in (ConvertMode.PARTIAL, ConvertMode.OBJECT)
#     353         and node._metadata.object_type in (None, dict)
#     354     ):
#
# File ~/.cache/pypoetry/virtualenvs/spatial-G_n0JvVf-py3.10/lib/python3.10/site-packages/hydra/_internal/instantiate/_instantiate2.py:92, in _call_target(_target_, _partial_, args, kwargs, full_key)
#      90 else:
#      91     try:
# ---> 92         return _target_(*args, **kwargs)
#      93     except Exception as e:
#      94         msg = f"Error in call to target '{_convert_target_to_string(_target_)}':\n{repr(e)}"
#
# File ~/spatial/spatial/merfish_dataset.py:541, in SyntheticDataset0.__init__(self, tol, *args, **kwargs)
#     539 def __init__(self, tol=1, *args, **kwargs):
#     540     self.tol = tol
# --> 541     super().__init__(*args, **kwargs)
#
# File ~/spatial/spatial/merfish_dataset.py:41, in MerfishDataset.__init__(self, root, n_neighbors, train, log_transform, include_celltypes, radius, non_response_genes_file, splits)
#      38 # response genes (columns in MERFISH)
#      39 self.response_genes = list(set(range(155)) - set(self.features))
# ---> 41 data_list = self.construct_graphs(
#      42     n_neighbors, train, log_transform, include_celltypes, radius, splits
#      43 )
#      45 with h5py.File(self.merfish_hdf5, "r") as h5f:
#      46     self.gene_names = h5f["gene_names"][:][~self.bad_genes].astype("U")
#
# File ~/spatial/spatial/merfish_dataset.py:331, in MerfishDataset.construct_graphs(self, n_neighbors, train, log_transform, include_celltypes, radius, splits)
#     327 data_list = []
#     329 for anid, breg in tqdm.tqdm(unique_slices):
#     330     data_list.append(
# --> 331         self.construct_graph(
#     332             data,
#     333             anid,
#     334             breg,
#     335             n_neighbors,
#     336             log_transform,
#     337             include_celltypes,
#     338             radius,
#     339             splits=splits,
#     340         )
#     341     )
#     343 return sum(data_list, [])
#
# File ~/spatial/spatial/merfish_dataset.py:212, in MerfishDataset.construct_graph(self, data, anid, breg, n_neighbors, log_transform, include_celltypes, radius, splits)
#     207 good = (data.anids == anid) & (data.bregs == breg)
#     209 # index 0 is behavior, index 1 is celltype,
#     210 # last 2 are the location. Will update it
#     211 # to be last 3 in the case that bregma is included in location.
# --> 212 data_for_this_slice = np.concatenate(
#     213     (
#     214         data.behavior[good].reshape(-1, 1),
#     215         data.celltypes[good].reshape(-1, 1),
#     216         data.expression[good],
#     217         data.locations[good],
#     218     ),
#     219     axis=1,
#     220 )
#     222 # graph splitting
#     223 graph_splits = [data_for_this_slice]
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
zero_separated_loss_dict
# Out:
# {0: {'Loss (MSE)': 0.06835666298866272,
#   'Loss for non-0s': 0.06468713283538818,
#   'Loss for 0s': 0.1363668292760849},
#  0.25: {'Loss (MSE)': 0.07899671792984009,
#   'Loss for non-0s': 0.06423668563365936,
#   'Loss for 0s': 0.1707461029291153},
#  0.5: {'Loss (MSE)': 0.10136043280363083,
#   'Loss for non-0s': 0.07536786049604416,
#   'Loss for 0s': 0.18052752315998077},
#  0.75: {'Loss (MSE)': 0.1291235089302063,
#   'Loss for non-0s': 0.10279928147792816,
#   'Loss for 0s': 0.17537926137447357},
#  1: {'Loss (MSE)': 0.17137663066387177,
#   'Loss for non-0s': 0.21866212785243988,
#   'Loss for 0s': 0.1372186243534088},
#  1.5: {'Loss (MSE)': 0.17394901812076569,
#   'Loss for non-0s': 0.4264993667602539,
#   'Loss for 0s': 0.08794506639242172},
#  2: {'Loss (MSE)': 0.12416359782218933,
#   'Loss for non-0s': 0.866157054901123,
#   'Loss for 0s': 0.03509766235947609}}

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams.update(plt.rcParamsDefault)

# %%
tol_list = [0, 0.25, 0.5, 0.75, 1, 1.5, 2]
plt.plot(tol_list, [zero_separated_loss_dict[tol]["Loss (MSE)"] for tol in tol_list], marker='o', label="Loss")
plt.plot(tol_list, [zero_separated_loss_dict[tol]["Loss for 0s"] for tol in tol_list], marker='o', label="Loss for 0s")
plt.plot(tol_list, [zero_separated_loss_dict[tol]["Loss for non-0s"] for tol in tol_list], marker='o', label="Loss for non-0s")
plt.legend(labels=["Loss", "Loss for 0s", "Loss for non-0s"], loc="upper left")
plt.title("Losses")
plt.xlabel("Gating Tolerance")
plt.ylabel("MSE")
_ = plt.show()
plt.savefig("zero_inflated_losses.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 tol_list = [0, 0.25, 0.5, 0.75, 1, 1.5, 2]
# ----> 2 plt.plot(tol_list, [zero_separated_loss_dict[tol]["Loss (MSE)"] for tol in tol_list], marker='o', label="Loss")
#       3 plt.plot(tol_list, [zero_separated_loss_dict[tol]["Loss for 0s"] for tol in tol_list], marker='o', label="Loss for 0s")
#       4 plt.plot(tol_list, [zero_separated_loss_dict[tol]["Loss for non-0s"] for tol in tol_list], marker='o', label="Loss for non-0s")
#
# NameError: name 'plt' is not defined

# %%
import hydra
from hydra.experimental import compose, initialize

test_loss_rad_dict = {}
zero_separated_loss_dict = {}


with initialize(config_path="../config"):
    cfg_from_terminal = compose(config_name="config8")
    OmegaConf.update(cfg_from_terminal, "model.kwargs.hidden_dimensions", [128, 128])
    OmegaConf.update(cfg_from_terminal, "training.logger_name", f"synthetic8")
    OmegaConf.update(cfg_from_terminal, "radius", 0)
    OmegaConf.update(cfg_from_terminal, "datasets.dataset.splits", 2)
    output = test(cfg_from_terminal)
    trainer, l1_losses, inputs, gene_expressions, celltypes, test_results = output
    test_loss_rad_dict = test_results[0]['test_loss']
    num_zeros = torch.sum(inputs[:, 0] == 0)
    n = len(inputs[:, 0])
    loss_for_non_zeros = (n / (n - num_zeros)) * torch.mean(((inputs[:, 0] - gene_expressions[:, 0]) ** 2) * (inputs[:, 0] != 0).reshape(1, -1))
    loss_for_zeros = (n / num_zeros) * torch.mean(((inputs[:, 0] - gene_expressions[:, 0]) ** 2) * (inputs[:, 0] == 0).reshape(1, -1))
    loss = torch.mean((inputs[:, 0] - gene_expressions[:, 0]) ** 2)
    zero_separated_loss_dict = {
        "Loss (MSE)": loss.item(),
        "Loss for non-0s": loss_for_non_zeros.item(),
        "Loss for 0s": loss_for_zeros.item()
    }
    
zero_separated_loss_dict
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 24/24 [00:26<00:00,  1.12s/it]
# /home/roko/spatial/data/raw/synth8.hdf5
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# Testing: 0it [00:00, ?it/s]
# TEST Profiler Report
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                                                          	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                                                           	|  -              	|  6951           	|  69.77          	|  100 %          	|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_test_evaluation                                                                                                                                                                             	|  68.813         	|  1              	|  68.813         	|  98.629         	|
# |  [Strategy]SingleDeviceStrategy.test_step                                                                                                                                                        	|  0.16626        	|  384            	|  63.842         	|  91.504         	|
# |  [EvaluationEpochLoop].test_dataloader_idx_0_next                                                                                                                                                	|  0.0097078      	|  384            	|  3.7278         	|  5.343          	|
# |  [Callback]TQDMProgressBar.on_test_batch_end                                                                                                                                                     	|  0.00092899     	|  384            	|  0.35673        	|  0.5113         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                                                  	|  0.0008463      	|  384            	|  0.32498        	|  0.46579        	|
# |  [LightningModule]MonetDense.transfer_batch_to_device                                                                                                                                            	|  0.0007747      	|  384            	|  0.29749        	|  0.42638        	|
# |  [Callback]TQDMProgressBar.on_test_start                                                                                                                                                         	|  0.011245       	|  1              	|  0.011245       	|  0.016118       	|
# |  [Callback]TQDMProgressBar.on_test_batch_start                                                                                                                                                   	|  1.268e-05      	|  384            	|  0.0048691      	|  0.0069788      	|
# |  [Callback]ModelSummary.on_test_batch_end                                                                                                                                                        	|  5.9286e-06     	|  384            	|  0.0022766      	|  0.003263       	|
# |  [LightningModule]MonetDense.test_step_end                                                                                                                                                       	|  3.3256e-06     	|  384            	|  0.001277       	|  0.0018304      	|
# |  [Callback]ModelSummary.on_test_batch_start                                                                                                                                                      	|  3.2894e-06     	|  384            	|  0.0012631      	|  0.0018104      	|
# |  [LightningModule]MonetDense.on_before_batch_transfer                                                                                                                                            	|  3.097e-06      	|  384            	|  0.0011892      	|  0.0017045      	|
# |  [Callback]GradientAccumulationScheduler.on_test_batch_start                                                                                                                                     	|  3.0146e-06     	|  384            	|  0.0011576      	|  0.0016592      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_test_batch_start	|  2.6325e-06     	|  384            	|  0.0010109      	|  0.0014489      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_test_batch_end  	|  2.561e-06      	|  384            	|  0.00098342     	|  0.0014095      	|
# |  [Callback]GradientAccumulationScheduler.on_test_batch_end                                                                                                                                       	|  2.4457e-06     	|  384            	|  0.00093916     	|  0.0013461      	|
# |  [LightningModule]MonetDense.on_after_batch_transfer                                                                                                                                             	|  2.2639e-06     	|  384            	|  0.00086934     	|  0.001246       	|
# |  [LightningModule]MonetDense.on_test_batch_end                                                                                                                                                   	|  2.1678e-06     	|  384            	|  0.00083244     	|  0.0011931      	|
# |  [LightningModule]MonetDense.on_test_batch_start                                                                                                                                                 	|  2.0031e-06     	|  384            	|  0.00076917     	|  0.0011024      	|
# |  [Strategy]SingleDeviceStrategy.test_step_end                                                                                                                                                    	|  1.6558e-06     	|  384            	|  0.00063584     	|  0.00091133     	|
# |  [Callback]TQDMProgressBar.on_test_end                                                                                                                                                           	|  0.00042796     	|  1              	|  0.00042796     	|  0.00061338     	|
# |  [LightningModule]MonetDense.on_test_model_train                                                                                                                                                 	|  0.00018207     	|  1              	|  0.00018207     	|  0.00026096     	|
# |  [LightningModule]MonetDense.on_test_model_eval                                                                                                                                                  	|  0.00010352     	|  1              	|  0.00010352     	|  0.00014838     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': None}.setup              	|  1.3878e-05     	|  1              	|  1.3878e-05     	|  1.9891e-05     	|
# |  [Callback]ModelSummary.on_test_end                                                                                                                                                              	|  9.565e-06      	|  1              	|  9.565e-06      	|  1.3709e-05     	|
# |  [Callback]ModelSummary.on_test_start                                                                                                                                                            	|  7.297e-06      	|  1              	|  7.297e-06      	|  1.0459e-05     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                                                 	|  7.177e-06      	|  1              	|  7.177e-06      	|  1.0287e-05     	|
# |  [LightningModule]MonetDense.configure_callbacks                                                                                                                                                 	|  6.71e-06       	|  1              	|  6.71e-06       	|  9.6173e-06     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                                                              	|  6.5e-06        	|  1              	|  6.5e-06        	|  9.3163e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_test_end                                                                                                                                                      	|  5.236e-06      	|  1              	|  5.236e-06      	|  7.5047e-06     	|
# |  [LightningModule]MonetDense.on_test_epoch_end                                                                                                                                                   	|  5.108e-06      	|  1              	|  5.108e-06      	|  7.3212e-06     	|
# |  [LightningModule]MonetDense.configure_sharded_model                                                                                                                                             	|  3.836e-06      	|  1              	|  3.836e-06      	|  5.4981e-06     	|
# |  [LightningModule]MonetDense.on_test_end                                                                                                                                                         	|  3.785e-06      	|  1              	|  3.785e-06      	|  5.425e-06      	|
# |  [Callback]ModelSummary.setup                                                                                                                                                                    	|  3.497e-06      	|  1              	|  3.497e-06      	|  5.0122e-06     	|
# |  [LightningModule]MonetDense.on_test_start                                                                                                                                                       	|  2.592e-06      	|  1              	|  2.592e-06      	|  3.7151e-06     	|
# |  [LightningModule]MonetDense.test_epoch_end                                                                                                                                                      	|  2.44e-06       	|  1              	|  2.44e-06       	|  3.4972e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_end                                                                                                                                                     	|  2.333e-06      	|  1              	|  2.333e-06      	|  3.3438e-06     	|
# |  [LightningModule]MonetDense.teardown                                                                                                                                                            	|  1.926e-06      	|  1              	|  1.926e-06      	|  2.7605e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_test_end                                                                                                                                             	|  1.867e-06      	|  1              	|  1.867e-06      	|  2.6759e-06     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                                                 	|  1.854e-06      	|  1              	|  1.854e-06      	|  2.6573e-06     	|
# |  [LightningModule]MonetDense.prepare_data                                                                                                                                                        	|  1.797e-06      	|  1              	|  1.797e-06      	|  2.5756e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_test_end        	|  1.532e-06      	|  1              	|  1.532e-06      	|  2.1958e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_start                                                                                                                                                   	|  1.516e-06      	|  1              	|  1.516e-06      	|  2.1729e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.teardown           	|  1.437e-06      	|  1              	|  1.437e-06      	|  2.0596e-06     	|
# |  [Callback]ModelSummary.on_test_epoch_end                                                                                                                                                        	|  1.418e-06      	|  1              	|  1.418e-06      	|  2.0324e-06     	|
# |  [Callback]GradientAccumulationScheduler.setup                                                                                                                                                   	|  1.369e-06      	|  1              	|  1.369e-06      	|  1.9622e-06     	|
# |  [LightningModule]MonetDense.setup                                                                                                                                                               	|  1.345e-06      	|  1              	|  1.345e-06      	|  1.9278e-06     	|
# |  [Callback]GradientAccumulationScheduler.teardown                                                                                                                                                	|  1.316e-06      	|  1              	|  1.316e-06      	|  1.8862e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_test_start                                                                                                                                           	|  1.287e-06      	|  1              	|  1.287e-06      	|  1.8446e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_test_epoch_start	|  1.204e-06      	|  1              	|  1.204e-06      	|  1.7257e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_test_epoch_end  	|  1.128e-06      	|  1              	|  1.128e-06      	|  1.6167e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_test_start      	|  1.125e-06      	|  1              	|  1.125e-06      	|  1.6124e-06     	|
# |  [Callback]ModelSummary.on_test_epoch_start                                                                                                                                                      	|  1.077e-06      	|  1              	|  1.077e-06      	|  1.5436e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_test_start                                                                                                                                                    	|  1.041e-06      	|  1              	|  1.041e-06      	|  1.492e-06      	|
# |  [Callback]GradientAccumulationScheduler.on_test_epoch_end                                                                                                                                       	|  1.013e-06      	|  1              	|  1.013e-06      	|  1.4519e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_test_epoch_start                                                                                                                                     	|  9.84e-07       	|  1              	|  9.84e-07       	|  1.4104e-06     	|
# |  [LightningModule]MonetDense.on_test_epoch_start                                                                                                                                                 	|  8.61e-07       	|  1              	|  8.61e-07       	|  1.2341e-06     	|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_loss           0.14432787895202637
#      test_loss: mse         0.14432787895202637
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# {'Loss (MSE)': 0.14432787895202637,
#  'Loss for non-0s': 0.04854154214262962,
#  'Loss for 0s': 1.1739932298660278}

# %%
torch.sum(gene_expressions[:, 0] == 0)
# Out:
# tensor(0)

# %%
inputs
# Out:
# tensor([[0.2091, 0.0979, 0.0044,  ..., 0.0429, 0.2568, 0.1001],
#         [0.1587, 0.0586, 0.0091,  ..., 0.0725, 0.0080, 0.0110],
#         [0.1272, 0.0419, 0.0811,  ..., 0.0620, 0.0398, 0.0980],
#         ...,
#         [0.0865, 0.0782, 0.1126,  ..., 0.1696, 0.1441, 0.0077],
#         [0.1343, 0.0864, 0.0276,  ..., 0.1115, 0.0504, 0.0668],
#         [0.2595, 0.1641, 0.0397,  ..., 0.0057, 0.0145, 0.0018]])

# %%
torch.set_printoptions(sci_mode=False)
torch.round(gene_expressions, decimals=4)
# Out:
# tensor([[     0.1806,      1.5100,     -2.2698,  ...,      2.4237,
#              -1.2052,      2.8728],
#         [     0.1502,     -0.8261,     -0.0012,  ...,     -0.3826,
#              -1.3962,      1.8240],
#         [     0.1346,     -1.9792,      0.9231,  ...,     -1.0029,
#              -1.1496,     -0.1602],
#         ...,
#         [     0.1785,      0.1571,     -0.1246,  ...,      1.8092,
#              -3.2476,      0.5719],
#         [     0.1861,      0.7607,      0.0453,  ...,     -0.8183,
#              -0.5509,      0.1121],
#         [     0.2606,     -0.1781,     -1.4081,  ...,     -0.3479,
#              -0.2700,      0.2911]])
