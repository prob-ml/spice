# %%
from packaging import version

import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats
import tensorboard as tb

# %%
major_ver, minor_ver, _ = version.parse(tb.__version__).release
assert major_ver >= 2 and minor_ver >= 3, \
    "This notebook requires TensorBoard 2.3 or later."
print("TensorBoard version", tb.__version__, "works for experimental purposes!")
# Out:
# TensorBoard version 2.8.0 works for experimental purposes!

# %%
experiment_id = "F2K2zZnlQzinJHv7To50fA"
experiment = tb.data.experimental.ExperimentFromDev(experiment_id)
df = experiment.get_scalars()
df
# Out:
#                                                  run            tag     step  \
# 0         MonetDense__[128, 128]__[0]__0__synthetic2          epoch        9
# 1         MonetDense__[128, 128]__[0]__0__synthetic2          epoch       19
# 2         MonetDense__[128, 128]__[0]__0__synthetic2          epoch       29
# 3         MonetDense__[128, 128]__[0]__0__synthetic2          epoch       39
# 4         MonetDense__[128, 128]__[0]__0__synthetic2          epoch       49
# ...                                              ...            ...      ...
# 1105675  MonetDense__[128, 128]__[0]__60__synthetic2  val_loss: mse  1289679
# 1105676  MonetDense__[128, 128]__[0]__60__synthetic2  val_loss: mse  1312709
# 1105677  MonetDense__[128, 128]__[0]__60__synthetic2  val_loss: mse  1335739
# 1105678  MonetDense__[128, 128]__[0]__60__synthetic2  val_loss: mse  1358769
# 1105679  MonetDense__[128, 128]__[0]__60__synthetic2  val_loss: mse  1381799
#
#             value
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# ...           ...
# 1105675  0.168415
# 1105676  0.163510
# 1105677  0.161328
# 1105678  0.167273
# 1105679  0.167568
#
# [1105680 rows x 4 columns]
