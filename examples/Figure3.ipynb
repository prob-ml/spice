# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lineplot(x = range(12,60,12), y=[1.88,3.64,5.39,6.83], marker = 'o')
sns.lineplot(x = range(12,60,12), y=[24.14,45.23,65.16,80.97], marker = 'o')
sns.lineplot(x = range(12,60,12), y=[2.10,2.69,3.43,4.19], marker = 'o')
sns.lineplot(x = range(6,36,6), y=[65.85,194.81,407.33,711.07,1611.61], marker = 'o')
plt.yscale('log')
plt.title("Training Time for Merfish Slices")
plt.xlabel("Number of Training Slices")
plt.ylabel("Log Time")
plt.legend(labels=["LightGBM", "deepST", "XGBoost", "MESSI"], loc="upper right")

# plt.rcParams['figure.dpi'] = 300
# plt.rcParams['savefig.dpi'] = 300
plt.savefig("training_time.png")

# %%
# LIGHTGBM 
# 12 slices, 1.88 minutes
# 24 slices, 3.64 minutes
# 36 slices, 5.39 minutes
# 48 slices, 6.83 minutes

# %%
# deepST
# 12 slices, (1448.248458147049/60 = 24.14 minutes)
# 24 slices, (2713.570953845978/60 = 45.23 minutes)
# 36 slices, (3909.5076580047607/60 = 65.16 minutes)
# 48 slices, (4857.994031190872/60 = 80.97 minutes)

# %%
# XGBoost
# 12 slices, 2.10 minutes
# 24 slices, 2.69 minutes
# 36 slices, 3.43 minutes
# 48 slices, 4.19 minutes

# %%
# MESSI
# 12 slices, 41.67 minutes
# 24 slices, 40.03 minutes
# 36 slices, 
# 48 slices,
