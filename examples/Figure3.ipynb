# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lineplot(x = range(1,3), y=[29, 29], marker = 'o')
sns.lineplot(x = range(1,3), y=[9.9, 3], marker = 'o')
sns.lineplot(x = range(1,3), y=[719, 31], marker = 'o')
sns.lineplot(x = range(1,3), y=[2.7, 1.5], marker = 'o')
plt.yscale('log')
plt.title("Training Time for Merfish Slices")
plt.xlabel("Number of Training Animals")
plt.ylabel("Log Time")
plt.show()
