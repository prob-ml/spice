# %%
from spatial.merfish_dataset import FilteredMerfishDataset

# %%
test = FilteredMerfishDataset("../data", neighbor_celltypes=True)
# Out:
# ../data/raw/merfish_messi.hdf5
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# There are 16 different cell types.
# ...
